# %%
import scanpy as sc
import time
from pyROMA.ROMA import *
import os
import pandas as pd
import anndata
print(os.getcwd())
print(ROMA)
# Out:
# /home/az/Projects/01_Curie/05_pyROMA/pyROMA_shared
# <class 'pyROMA.ROMA.ROMA'>

# %%
# Initialize ROMA
roma = ROMA()
# this should be empty at first
roma.adata

# %%
roma
# Out:
# scROMA

# %%
df = pd.read_csv('/home/az/Projects/01_Curie/06.1_pyROMA_Sofia_results/pbulk_matrix_Rade2024_normalized.csv',index_col=0)
print(df.shape)
df.head()
# Out:
# (36602, 177)
#              MXMERZ002A_02_clusterCD4 T-Cell  MXMERZ002A_02_clusterCD8 T-Cell  \
# CAR-BCMA                           -0.734156                        -0.734156
# MIR1302-2HG                        -0.734156                        -0.734156
# FAM138A                            -0.734156                        -0.734156
# OR4F5                              -0.734156                        -0.734156
# AL627309.1                         -0.734156                        -0.734156
#
#              MXMERZ002A_02_clustercDC  MXMERZ002A_02_clusterMono CD14  \
# CAR-BCMA                    -0.734156                       -0.734156
# MIR1302-2HG                 -0.734156                       -0.052713
# FAM138A                     -0.734156                       -0.734156
# OR4F5                       -0.734156                       -0.734156
# AL627309.1                  -0.734156                       -0.052713
#
#              MXMERZ002A_02_clusterMono CD16  MXMERZ002A_02_clusterNK  \
# CAR-BCMA                          -0.734156                -0.734156
# MIR1302-2HG                       -0.734156                -0.734156
# FAM138A                           -0.734156                -0.734156
# OR4F5                             -0.734156                -0.734156
# AL627309.1                        -0.734156                -0.734156
#
#              MXMERZ002A_02_clusterpDC  MXMERZ002A_02_clusterPlasma cell  \
# CAR-BCMA                    -0.734156                         -0.734156
# MIR1302-2HG                 -0.734156                         -0.734156
# FAM138A                     -0.734156                         -0.734156
# OR4F5                       -0.734156                         -0.734156
# AL627309.1                  -0.734156                         -0.230462
#
#              MXMERZ002A_02_clusterProgenitor  MXMERZ002A_03_clusterB-Cell  \
# CAR-BCMA                           -0.734156                    -0.734156
# MIR1302-2HG                        -0.734156                    -0.734156
# FAM138A                            -0.734156                    -0.734156
# OR4F5                              -0.734156                    -0.734156
# AL627309.1                         -0.734156                     0.829174
#
#              ...  MXMERZ002A_24_clusterPlasma cell  \
# CAR-BCMA     ...                         -0.734156
# MIR1302-2HG  ...                         -0.734156
# FAM138A      ...                         -0.734156
# OR4F5        ...                         -0.734156
# AL627309.1   ...                         -0.734156
#
#              MXMERZ002A_24_clusterProgenitor  MXMERZ002A_25_clusterB-Cell  \
# CAR-BCMA                           -0.734156                    -0.734156
# MIR1302-2HG                        -0.734156                    -0.734156
# FAM138A                            -0.734156                    -0.734156
# OR4F5                              -0.734156                    -0.734156
# AL627309.1                         -0.734156                    -0.734156
#
#              MXMERZ002A_25_clusterCD4 T-Cell  MXMERZ002A_25_clusterCD8 T-Cell  \
# CAR-BCMA                           -0.734156                        -0.734156
# MIR1302-2HG                        -0.734156                        -0.734156
# FAM138A                            -0.734156                        -0.734156
# OR4F5                              -0.734156                        -0.734156
# AL627309.1                         -0.734156                        -0.734156
#
#              MXMERZ002A_25_clustercDC  MXMERZ002A_25_clusterMono CD14  \
# CAR-BCMA                    -0.734156                       -0.734156
# MIR1302-2HG                 -0.734156                       -0.734156
# FAM138A                     -0.734156                       -0.734156
# OR4F5                       -0.734156                       -0.734156
# AL627309.1                  -0.734156                        2.151458
#
#              MXMERZ002A_25_clusterMono CD16  MXMERZ002A_25_clusterNK  \
# CAR-BCMA                          -0.734156                -0.734156
# MIR1302-2HG                       -0.734156                -0.734156
# FAM138A                           -0.734156                -0.734156
# OR4F5                             -0.734156                -0.734156
# AL627309.1                        -0.734156                -0.734156
#
#              MXMERZ002A_25_clusterpDC
# CAR-BCMA                    -0.734156
# MIR1302-2HG                 -0.734156
# FAM138A                     -0.734156
# OR4F5                       -0.734156
# AL627309.1                  -0.734156
#
# [5 rows x 177 columns]

# %%
adata = anndata.AnnData(df.T)
adata
# Out:
# AnnData object with n_obs × n_vars = 177 × 36602

# %%
# Genes are in the var
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [CAR-BCMA, MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3, AL627309.2, AL627309.5, AL627309.4, AP006222.2, AL732372.1, OR4F29, AC114498.1, OR4F16, AL669831.2, LINC01409, FAM87B, LINC01128, LINC00115, FAM41C, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.1, AGRN, AL645608.5, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, AL139287.1, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20-AS1, MRPL20, AL391244.2, ANKRD65, AL391244.1, TMEM88B, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.4, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, ...]
#
# [36602 rows x 0 columns]

# %%
roma.adata = adata
print(roma.adata)
# Out:
# AnnData object with n_obs × n_vars = 177 × 36602

# %%
os.chdir('/home/az/Projects/01_Curie/06.1_pyROMA_Sofia_results/')
roma.gmt ='h.all.v2023.2.Hs.symbols.gmt'
# This function allows to load the patwhays into dictionary
pathways = roma.read_gmt_to_dict('h.all.v2023.2.Hs.symbols.gmt')

# %%
pathways_to_check = 'all'

# %%
roma
# Out:
# scROMA

# %%
# Filter pathways that have less genes than min_n_number
roma.min_n_genes
# Out:
# 10

# %%
# Set the number of iterations to create the null distribution
iters = 1000

# %%
# Granularity of the null geneset size, from 0 to 100, less is more precise
roma.approx_int = 1

# %%
start = time.time()
# run it without outlier detection
roma.compute(pathways_to_check, parallel=True, incremental=False, iters=iters, loocv_on=False)
end = time.time()
minutes, seconds = divmod(end - start, 60)
print(f"Truncated Parallel {iters} iterations, running time (min): " + "{:0>2}:{:05.2f}".format(int(minutes),seconds))

adata
# Out:
# Processing gene set: HALLMARK_NOTCH_SIGNALING | len of subsetlist:  32
# Processing gene set: HALLMARK_ANGIOGENESIS | len of subsetlist:  36
# Processing gene set: HALLMARK_HEDGEHOG_SIGNALING | len of subsetlist:  36
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_PANCREAS_BETA_CELLS | len of subsetlist:  40
# Processing gene set: HALLMARK_WNT_BETA_CATENIN_SIGNALING | len of subsetlist:  42
# Processing gene set: HALLMARK_APICAL_SURFACE | len of subsetlist:  44
# Processing gene set: HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY | len of subsetlist:  49
# Processing gene set: HALLMARK_TGF_BETA_SIGNALING | len of subsetlist:  54
# Processing gene set: HALLMARK_MYC_TARGETS_V2 | len of subsetlist:  57
# Processing gene set: HALLMARK_CHOLESTEROL_HOMEOSTASIS | len of subsetlist:  74
# Processing gene set: HALLMARK_IL6_JAK_STAT3_SIGNALING | len of subsetlist:  87
# Processing gene set: HALLMARK_PROTEIN_SECRETION | len of subsetlist:  96
# Processing gene set: HALLMARK_INTERFERON_ALPHA_RESPONSE | len of subsetlist:  96
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ANDROGEN_RESPONSE | len of subsetlist:  99
# Processing gene set: HALLMARK_PEROXISOME | len of subsetlist:  104
# Processing gene set: HALLMARK_PI3K_AKT_MTOR_SIGNALING | len of subsetlist:  105
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_BILE_ACID_METABOLISM | len of subsetlist:  112
# Processing gene set: HALLMARK_UNFOLDED_PROTEIN_RESPONSE | len of subsetlist:  109
# Processing gene set: HALLMARK_SPERMATOGENESIS | len of subsetlist:  134
# Processing gene set: HALLMARK_COAGULATION | len of subsetlist:  138
# Processing gene set: HALLMARK_UV_RESPONSE_DN | len of subsetlist:  144
# Processing gene set: HALLMARK_DNA_REPAIR | len of subsetlist:  149
# Processing gene set: HALLMARK_FATTY_ACID_METABOLISM | len of subsetlist:  156
# Processing gene set: HALLMARK_UV_RESPONSE_UP | len of subsetlist:  156
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_APOPTOSIS | len of subsetlist:  159
# Processing gene set: HALLMARK_IL2_STAT5_SIGNALING | len of subsetlist:  198
# Processing gene set: HALLMARK_MITOTIC_SPINDLE | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ADIPOGENESIS | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ALLOGRAFT_REJECTION | len of subsetlist:  196
# Processing gene set: HALLMARK_APICAL_JUNCTION | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_COMPLEMENT | len of subsetlist:  200
# Processing gene set: HALLMARK_E2F_TARGETS | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION | len of subsetlist:  200
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ESTROGEN_RESPONSE_EARLY | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ESTROGEN_RESPONSE_LATE | len of subsetlist:  197
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_G2M_CHECKPOINT | len of subsetlist:  195
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_GLYCOLYSIS | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_HEME_METABOLISM | len of subsetlist:  194
# Processing gene set: HALLMARK_HYPOXIA | len of subsetlist:  200
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_INFLAMMATORY_RESPONSE | len of subsetlist:  200
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_INTERFERON_GAMMA_RESPONSE | len of subsetlist:  197
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_KRAS_SIGNALING_DN | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_KRAS_SIGNALING_UP | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_MTORC1_SIGNALING | len of subsetlist:  197
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_MYC_TARGETS_V1 | len of subsetlist:  195
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_MYOGENESIS | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_OXIDATIVE_PHOSPHORYLATION | len of subsetlist:  200
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_P53_PATHWAY | len of subsetlist:  196
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_TNFA_SIGNALING_VIA_NFKB | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_XENOBIOTIC_METABOLISM | len of subsetlist:  196
# Took null distribution from previous calculation
#   Finished : Truncated Parallel 1000 iterations, running time (min): 09:32.95
# AnnData object with n_obs × n_vars = 177 × 36602
#     uns: 'ROMA', 'ROMA_stats', 'ROMA_active_modules'

# %%
roma
# Out:
# scROMA: module activities are computed

# %%
roma.adata
# Out:
# AnnData object with n_obs × n_vars = 177 × 36602
#     uns: 'ROMA', 'ROMA_stats', 'ROMA_active_modules'

# %%
roma.adata.uns['ROMA_stats']
# Out:
#                                                   L1  p_value  Median_Exp  \
# HALLMARK_NOTCH_SIGNALING                    0.186630      1.0   11.819363
# HALLMARK_ANGIOGENESIS                       0.290029      1.0    1.266276
# HALLMARK_HEDGEHOG_SIGNALING                 0.293255      1.0    0.043063
# HALLMARK_PANCREAS_BETA_CELLS                0.413766      1.0    0.000372
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         0.164617      1.0    8.963342
# HALLMARK_APICAL_SURFACE                     0.408088      1.0    0.008099
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY    0.034273      1.0   15.332358
# HALLMARK_TGF_BETA_SIGNALING                 0.114584      1.0   14.891113
# HALLMARK_MYC_TARGETS_V2                     0.040981      1.0   14.817068
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            0.108790      1.0   11.401582
# HALLMARK_IL6_JAK_STAT3_SIGNALING            0.204686      1.0   11.293889
# HALLMARK_PROTEIN_SECRETION                  0.089786      1.0   15.085421
# HALLMARK_INTERFERON_ALPHA_RESPONSE          0.103584      1.0   17.791852
# HALLMARK_ANDROGEN_RESPONSE                  0.093551      1.0   11.480212
# HALLMARK_PEROXISOME                         0.108705      1.0   13.194880
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            0.087415      1.0   13.767910
# HALLMARK_BILE_ACID_METABOLISM               0.118171      1.0    9.176507
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          0.062535      1.0   14.610491
# HALLMARK_SPERMATOGENESIS                    0.166645      1.0    2.969963
# HALLMARK_COAGULATION                        0.249742      1.0    2.036126
# HALLMARK_UV_RESPONSE_DN                     0.130725      1.0    9.533464
# HALLMARK_DNA_REPAIR                         0.050361      1.0   14.414139
# HALLMARK_FATTY_ACID_METABOLISM              0.109713      1.0   12.795625
# HALLMARK_UV_RESPONSE_UP                     0.136950      1.0   11.868653
# HALLMARK_APOPTOSIS                          0.108955      1.0   11.982350
# HALLMARK_IL2_STAT5_SIGNALING                0.104464      1.0   10.365158
# HALLMARK_MITOTIC_SPINDLE                    0.063142      1.0   12.740881
# HALLMARK_ADIPOGENESIS                       0.117529      1.0   13.928635
# HALLMARK_ALLOGRAFT_REJECTION                0.373699      1.0    2.297321
# HALLMARK_APICAL_JUNCTION                    0.198728      1.0    3.959327
# HALLMARK_COMPLEMENT                         0.224628      1.0   10.584624
# HALLMARK_E2F_TARGETS                        0.042237      1.0   14.084280
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.231684      1.0    0.327647
# HALLMARK_ESTROGEN_RESPONSE_EARLY            0.206748      1.0    2.738705
# HALLMARK_ESTROGEN_RESPONSE_LATE             0.207768      1.0    2.243888
# HALLMARK_G2M_CHECKPOINT                     0.055064      1.0   13.418979
# HALLMARK_GLYCOLYSIS                         0.119386      1.0   10.769470
# HALLMARK_HEME_METABOLISM                    0.101866      1.0   11.611890
# HALLMARK_HYPOXIA                            0.159497      1.0    9.797448
# HALLMARK_INFLAMMATORY_RESPONSE              0.253826      1.0    8.573276
# HALLMARK_INTERFERON_GAMMA_RESPONSE          0.090939      1.0   16.549603
# HALLMARK_KRAS_SIGNALING_DN                  0.162222      1.0    0.539664
# HALLMARK_KRAS_SIGNALING_UP                  0.242198      1.0    4.132073
# HALLMARK_MTORC1_SIGNALING                   0.064363      1.0   14.444754
# HALLMARK_MYC_TARGETS_V1                     0.059385      1.0   14.899119
# HALLMARK_MYOGENESIS                         0.190573      1.0    0.719570
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.040600      1.0   15.190930
# HALLMARK_P53_PATHWAY                        0.111732      1.0   11.758911
# HALLMARK_TNFA_SIGNALING_VIA_NFKB            0.124498      1.0   13.993923
# HALLMARK_XENOBIOTIC_METABOLISM              0.174072      1.0    8.996857
#
#                                              q_value
# HALLMARK_NOTCH_SIGNALING                    0.001314
# HALLMARK_ANGIOGENESIS                       0.329216
# HALLMARK_HEDGEHOG_SIGNALING                 0.969031
# HALLMARK_PANCREAS_BETA_CELLS                0.969031
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         0.001314
# HALLMARK_APICAL_SURFACE                     0.969031
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY    0.001314
# HALLMARK_TGF_BETA_SIGNALING                 0.001314
# HALLMARK_MYC_TARGETS_V2                     0.001314
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            0.001314
# HALLMARK_IL6_JAK_STAT3_SIGNALING            0.001314
# HALLMARK_PROTEIN_SECRETION                  0.001314
# HALLMARK_INTERFERON_ALPHA_RESPONSE          0.001314
# HALLMARK_ANDROGEN_RESPONSE                  0.001314
# HALLMARK_PEROXISOME                         0.001314
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            0.001314
# HALLMARK_BILE_ACID_METABOLISM               0.001314
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          0.001314
# HALLMARK_SPERMATOGENESIS                    0.009746
# HALLMARK_COAGULATION                        0.034849
# HALLMARK_UV_RESPONSE_DN                     0.001314
# HALLMARK_DNA_REPAIR                         0.001314
# HALLMARK_FATTY_ACID_METABOLISM              0.001314
# HALLMARK_UV_RESPONSE_UP                     0.001314
# HALLMARK_APOPTOSIS                          0.001314
# HALLMARK_IL2_STAT5_SIGNALING                0.001314
# HALLMARK_MITOTIC_SPINDLE                    0.001314
# HALLMARK_ADIPOGENESIS                       0.001314
# HALLMARK_ALLOGRAFT_REJECTION                0.014271
# HALLMARK_APICAL_JUNCTION                    0.001314
# HALLMARK_COMPLEMENT                         0.001314
# HALLMARK_E2F_TARGETS                        0.001314
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.969031
# HALLMARK_ESTROGEN_RESPONSE_EARLY            0.002562
# HALLMARK_ESTROGEN_RESPONSE_LATE             0.006244
# HALLMARK_G2M_CHECKPOINT                     0.001314
# HALLMARK_GLYCOLYSIS                         0.001314
# HALLMARK_HEME_METABOLISM                    0.001314
# HALLMARK_HYPOXIA                            0.001314
# HALLMARK_INFLAMMATORY_RESPONSE              0.001314
# HALLMARK_INTERFERON_GAMMA_RESPONSE          0.001314
# HALLMARK_KRAS_SIGNALING_DN                  0.889328
# HALLMARK_KRAS_SIGNALING_UP                  0.001314
# HALLMARK_MTORC1_SIGNALING                   0.001314
# HALLMARK_MYC_TARGETS_V1                     0.001314
# HALLMARK_MYOGENESIS                         0.705961
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.001314
# HALLMARK_P53_PATHWAY                        0.001314
# HALLMARK_TNFA_SIGNALING_VIA_NFKB            0.001314
# HALLMARK_XENOBIOTIC_METABOLISM              0.001314

# %%
type(roma.adata)
# Out:
# anndata._core.anndata.AnnData

# %%
type(adata.uns['ROMA'])
# Out:
# dict

# %%
type(adata.uns['ROMA_stats'])
# Out:
# pandas.core.frame.DataFrame

# %%
def save_ROMA_results(adata, path):
    # saves the adata to a path
    import pickle 
    d = adata.uns['ROMA']

    with open(f'{path}.pickle', 'wb') as handle:
        pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)

    del adata.uns['ROMA']
    adata.write(f"{path}.h5ad")

    return

def load_ROMA_results(path):
    # loads the results into adata
    import pickle
    import scanpy as sc 

    with open(f'{path}.pickle', 'rb') as handle:
        d = pickle.load(handle)

    adata = sc.read_h5ad(f'{path}.h5ad')
    adata.uns['ROMA'] = d

    return adata

# %%
adata_backup = roma.adata.copy()

# %%
path_to_save = '/home/az/Projects/01_Curie/06.1_pyROMA_Sofia_results/pyroma_outputs/RadeData'
save_ROMA_results(adata=roma.adata, path=path_to_save)

# %%
del roma.adata

# %%
roma.adata
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 roma.adata
#
# AttributeError: 'ROMA' object has no attribute 'adata'

# %%
roma.adata = load_ROMA_results(path_to_save)

# %%
roma.adata
# Out:
# AnnData object with n_obs × n_vars = 177 × 36602
#     uns: 'ROMA_active_modules', 'ROMA_stats', 'ROMA'

# %%
roma.adata.uns['ROMA_stats'].to_csv('pyroma_outputs/ROMA_stats.csv')

# %% [markdown]
# # Compare rROMA and pyROMA

# %%
rROMA_df = pd.read_csv('/home/az/Projects/01_Curie/06.1_pyROMA_Sofia_results/roma_outputs/RadeData_module_matrix.csv', index_col=[0])
rROMA_df.head()
# Out:
#                                     L1  Median L1  ppv L1     L1/L2  \
# HALLMARK_ADIPOGENESIS         0.129883   0.198628    1.00  0.974184
# HALLMARK_ALLOGRAFT_REJECTION  0.390254   0.198628    0.00  4.241984
# HALLMARK_ANDROGEN_RESPONSE    0.115085   0.211010    1.00  1.017066
# HALLMARK_ANGIOGENESIS         0.296008   0.260650    0.24  1.338702
# HALLMARK_APICAL_JUNCTION      0.234288   0.198628    0.01  1.688134
#
#                               Median L1/L2  ppv L1/L2  Median Exp  \
# HALLMARK_ADIPOGENESIS             1.425571       1.00    9.257435
# HALLMARK_ALLOGRAFT_REJECTION      1.425571       0.00   -0.769921
# HALLMARK_ANDROGEN_RESPONSE        1.449478       1.00   -6.831589
# HALLMARK_ANGIOGENESIS             1.640605       0.76   -0.154860
# HALLMARK_APICAL_JUNCTION          1.425571       0.22   -0.423093
#
#                               ppv Median Exp      q L1   q L1/L2  q Median Exp
# HALLMARK_ADIPOGENESIS                   0.00  1.000000  1.000000      0.000000
# HALLMARK_ALLOGRAFT_REJECTION            0.98  0.000000  0.000000      0.990625
# HALLMARK_ANDROGEN_RESPONSE              0.00  1.000000  1.000000      0.000000
# HALLMARK_ANGIOGENESIS                   0.96  0.666667  1.000000      0.990625
# HALLMARK_APICAL_JUNCTION                0.99  0.041667  0.676471      0.990625

# %%
pyroma = roma.adata.uns['ROMA_stats'].copy()
pyroma.head()
# Out:
#                                            L1  p_value  Median_Exp   q_value
# HALLMARK_NOTCH_SIGNALING             0.186630      1.0   11.819363  0.001314
# HALLMARK_ANGIOGENESIS                0.290029      1.0    1.266276  0.329216
# HALLMARK_HEDGEHOG_SIGNALING          0.293255      1.0    0.043063  0.969031
# HALLMARK_PANCREAS_BETA_CELLS         0.413766      1.0    0.000372  0.969031
# HALLMARK_WNT_BETA_CATENIN_SIGNALING  0.164617      1.0    8.963342  0.001314

# %%
# Extract Median Exp L1

# %%
rROMA_df.shape
# Out:
# (50, 11)

# %%
pyroma.shape
# Out:
# (50, 4)

# %%
merged_df = pd.merge(rROMA_df, pyroma, left_index=True, right_index=True, suffixes=('_R', '_py'))
merged_df.head()
# Out:
#                                   L1_R  Median L1  ppv L1     L1/L2  \
# HALLMARK_ADIPOGENESIS         0.129883   0.198628    1.00  0.974184
# HALLMARK_ALLOGRAFT_REJECTION  0.390254   0.198628    0.00  4.241984
# HALLMARK_ANDROGEN_RESPONSE    0.115085   0.211010    1.00  1.017066
# HALLMARK_ANGIOGENESIS         0.296008   0.260650    0.24  1.338702
# HALLMARK_APICAL_JUNCTION      0.234288   0.198628    0.01  1.688134
#
#                               Median L1/L2  ppv L1/L2  Median Exp  \
# HALLMARK_ADIPOGENESIS             1.425571       1.00    9.257435
# HALLMARK_ALLOGRAFT_REJECTION      1.425571       0.00   -0.769921
# HALLMARK_ANDROGEN_RESPONSE        1.449478       1.00   -6.831589
# HALLMARK_ANGIOGENESIS             1.640605       0.76   -0.154860
# HALLMARK_APICAL_JUNCTION          1.425571       0.22   -0.423093
#
#                               ppv Median Exp      q L1   q L1/L2  \
# HALLMARK_ADIPOGENESIS                   0.00  1.000000  1.000000
# HALLMARK_ALLOGRAFT_REJECTION            0.98  0.000000  0.000000
# HALLMARK_ANDROGEN_RESPONSE              0.00  1.000000  1.000000
# HALLMARK_ANGIOGENESIS                   0.96  0.666667  1.000000
# HALLMARK_APICAL_JUNCTION                0.99  0.041667  0.676471
#
#                               q Median Exp     L1_py  p_value  Median_Exp  \
# HALLMARK_ADIPOGENESIS             0.000000  0.117529      1.0   13.928635
# HALLMARK_ALLOGRAFT_REJECTION      0.990625  0.373699      1.0    2.297321
# HALLMARK_ANDROGEN_RESPONSE        0.000000  0.093551      1.0   11.480212
# HALLMARK_ANGIOGENESIS             0.990625  0.290029      1.0    1.266276
# HALLMARK_APICAL_JUNCTION          0.990625  0.198728      1.0    3.959327
#
#                                q_value
# HALLMARK_ADIPOGENESIS         0.001314
# HALLMARK_ALLOGRAFT_REJECTION  0.014271
# HALLMARK_ANDROGEN_RESPONSE    0.001314
# HALLMARK_ANGIOGENESIS         0.329216
# HALLMARK_APICAL_JUNCTION      0.001314

# %%
merged_df.shape
# Out:
# (50, 15)

# %%
merged_df[['L1_R', 'L1_py', 'ppv L1','p_value', 'Median Exp', 'Median_Exp','q Median Exp', 'q_value' ]]
# Out:
#                                                 L1_R     L1_py  ppv L1  \
# HALLMARK_ADIPOGENESIS                       0.129883  0.117529    1.00
# HALLMARK_ALLOGRAFT_REJECTION                0.390254  0.373699    0.00
# HALLMARK_ANDROGEN_RESPONSE                  0.115085  0.093551    1.00
# HALLMARK_ANGIOGENESIS                       0.296008  0.290029    0.24
# HALLMARK_APICAL_JUNCTION                    0.234288  0.198728    0.01
# HALLMARK_APICAL_SURFACE                     0.410351  0.408088    0.00
# HALLMARK_APOPTOSIS                          0.212387  0.108955    0.24
# HALLMARK_BILE_ACID_METABOLISM               0.209202  0.118171    0.46
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            0.156816  0.108790    0.99
# HALLMARK_COAGULATION                        0.262133  0.249742    0.01
# HALLMARK_COMPLEMENT                         0.311857  0.224628    0.00
# HALLMARK_DNA_REPAIR                         0.054802  0.050361    1.00
# HALLMARK_E2F_TARGETS                        0.052095  0.042237    1.00
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.247274  0.231684    0.00
# HALLMARK_ESTROGEN_RESPONSE_EARLY            0.247689  0.206748    0.00
# HALLMARK_ESTROGEN_RESPONSE_LATE             0.244319  0.207768    0.00
# HALLMARK_FATTY_ACID_METABOLISM              0.113011  0.109713    1.00
# HALLMARK_G2M_CHECKPOINT                     0.079111  0.055064    1.00
# HALLMARK_GLYCOLYSIS                         0.165898  0.119386    1.00
# HALLMARK_HEDGEHOG_SIGNALING                 0.300483  0.293255    0.20
# HALLMARK_HEME_METABOLISM                    0.167447  0.101866    1.00
# HALLMARK_HYPOXIA                            0.206203  0.159497    0.31
# HALLMARK_IL2_STAT5_SIGNALING                0.254344  0.104464    0.00
# HALLMARK_IL6_JAK_STAT3_SIGNALING            0.257806  0.204686    0.07
# HALLMARK_INFLAMMATORY_RESPONSE              0.303830  0.253826    0.00
# HALLMARK_INTERFERON_ALPHA_RESPONSE          0.113747  0.103584    1.00
# HALLMARK_INTERFERON_GAMMA_RESPONSE          0.115875  0.090939    1.00
# HALLMARK_KRAS_SIGNALING_DN                  0.175279  0.162222    0.95
# HALLMARK_KRAS_SIGNALING_UP                  0.270726  0.242198    0.00
# HALLMARK_MITOTIC_SPINDLE                    0.069785  0.063142    1.00
# HALLMARK_MTORC1_SIGNALING                   0.071542  0.064363    1.00
# HALLMARK_MYC_TARGETS_V1                     0.055770  0.059385    1.00
# HALLMARK_MYC_TARGETS_V2                     0.044532  0.040981    1.00
# HALLMARK_MYOGENESIS                         0.213694  0.190573    0.16
# HALLMARK_NOTCH_SIGNALING                    0.208068  0.186630    0.95
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.048424  0.040600    1.00
# HALLMARK_P53_PATHWAY                        0.163679  0.111732    1.00
# HALLMARK_PANCREAS_BETA_CELLS                0.418310  0.413766    0.00
# HALLMARK_PEROXISOME                         0.121004  0.108705    1.00
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            0.088799  0.087415    1.00
# HALLMARK_PROTEIN_SECRETION                  0.093887  0.089786    1.00
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY    0.043703  0.034273    1.00
# HALLMARK_SPERMATOGENESIS                    0.173877  0.166645    0.95
# HALLMARK_TGF_BETA_SIGNALING                 0.140248  0.114584    1.00
# HALLMARK_TNFA_SIGNALING_VIA_NFKB            0.166778  0.124498    1.00
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          0.069121  0.062535    1.00
# HALLMARK_UV_RESPONSE_DN                     0.155753  0.130725    1.00
# HALLMARK_UV_RESPONSE_UP                     0.179762  0.136950    0.88
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         0.293957  0.164617    0.24
# HALLMARK_XENOBIOTIC_METABOLISM              0.209181  0.174072    0.28
#
#                                             p_value  Median Exp  Median_Exp  \
# HALLMARK_ADIPOGENESIS                           1.0    9.257435   13.928635
# HALLMARK_ALLOGRAFT_REJECTION                    1.0   -0.769921    2.297321
# HALLMARK_ANDROGEN_RESPONSE                      1.0   -6.831589   11.480212
# HALLMARK_ANGIOGENESIS                           1.0   -0.154860    1.266276
# HALLMARK_APICAL_JUNCTION                        1.0   -0.423093    3.959327
# HALLMARK_APICAL_SURFACE                         1.0   -0.191439    0.008099
# HALLMARK_APOPTOSIS                              1.0    3.690577   11.982350
# HALLMARK_BILE_ACID_METABOLISM                   1.0    0.318406    9.176507
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                1.0   -5.151147   11.401582
# HALLMARK_COAGULATION                            1.0   -0.600306    2.036126
# HALLMARK_COMPLEMENT                             1.0   -3.590742   10.584624
# HALLMARK_DNA_REPAIR                             1.0   -9.966074   14.414139
# HALLMARK_E2F_TARGETS                            1.0    9.450042   14.084280
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION      1.0   -0.991621    0.327647
# HALLMARK_ESTROGEN_RESPONSE_EARLY                1.0   -0.330045    2.738705
# HALLMARK_ESTROGEN_RESPONSE_LATE                 1.0   -0.767386    2.243888
# HALLMARK_FATTY_ACID_METABOLISM                  1.0    8.024034   12.795625
# HALLMARK_G2M_CHECKPOINT                         1.0   -8.325046   13.418979
# HALLMARK_GLYCOLYSIS                             1.0   -3.161271   10.769470
# HALLMARK_HEDGEHOG_SIGNALING                     1.0   -0.774146    0.043063
# HALLMARK_HEME_METABOLISM                        1.0    3.111260   11.611890
# HALLMARK_HYPOXIA                                1.0   -2.789599    9.797448
# HALLMARK_IL2_STAT5_SIGNALING                    1.0    0.079694   10.365158
# HALLMARK_IL6_JAK_STAT3_SIGNALING                1.0    6.547266   11.293889
# HALLMARK_INFLAMMATORY_RESPONSE                  1.0    4.757414    8.573276
# HALLMARK_INTERFERON_ALPHA_RESPONSE              1.0   13.594840   17.791852
# HALLMARK_INTERFERON_GAMMA_RESPONSE              1.0   11.428728   16.549603
# HALLMARK_KRAS_SIGNALING_DN                      1.0    2.731300    0.539664
# HALLMARK_KRAS_SIGNALING_UP                      1.0    0.209971    4.132073
# HALLMARK_MITOTIC_SPINDLE                        1.0    7.721097   12.740881
# HALLMARK_MTORC1_SIGNALING                       1.0  -10.271260   14.444754
# HALLMARK_MYC_TARGETS_V1                         1.0  -11.083112   14.899119
# HALLMARK_MYC_TARGETS_V2                         1.0   10.608229   14.817068
# HALLMARK_MYOGENESIS                             1.0    1.085115    0.719570
# HALLMARK_NOTCH_SIGNALING                        1.0   -6.026655   11.819363
# HALLMARK_OXIDATIVE_PHOSPHORYLATION              1.0  -11.410719   15.190930
# HALLMARK_P53_PATHWAY                            1.0    5.118835   11.758911
# HALLMARK_PANCREAS_BETA_CELLS                    1.0    0.481904    0.000372
# HALLMARK_PEROXISOME                             1.0    8.007085   13.194880
# HALLMARK_PI3K_AKT_MTOR_SIGNALING                1.0    9.183649   13.767910
# HALLMARK_PROTEIN_SECRETION                      1.0   10.900896   15.085421
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        1.0   10.828462   15.332358
# HALLMARK_SPERMATOGENESIS                        1.0    1.692436    2.969963
# HALLMARK_TGF_BETA_SIGNALING                     1.0   10.231111   14.891113
# HALLMARK_TNFA_SIGNALING_VIA_NFKB                1.0    8.625433   13.993923
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE              1.0   10.216817   14.610491
# HALLMARK_UV_RESPONSE_DN                         1.0   -4.328813    9.533464
# HALLMARK_UV_RESPONSE_UP                         1.0    5.846261   11.868653
# HALLMARK_WNT_BETA_CATENIN_SIGNALING             1.0    0.079378    8.963342
# HALLMARK_XENOBIOTIC_METABOLISM                  1.0   -2.744293    8.996857
#
#                                             q Median Exp   q_value
# HALLMARK_ADIPOGENESIS                           0.000000  0.001314
# HALLMARK_ALLOGRAFT_REJECTION                    0.990625  0.014271
# HALLMARK_ANDROGEN_RESPONSE                      0.000000  0.001314
# HALLMARK_ANGIOGENESIS                           0.990625  0.329216
# HALLMARK_APICAL_JUNCTION                        0.990625  0.001314
# HALLMARK_APICAL_SURFACE                         0.990625  0.969031
# HALLMARK_APOPTOSIS                              0.546713  0.001314
# HALLMARK_BILE_ACID_METABOLISM                   0.990625  0.001314
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                0.000000  0.001314
# HALLMARK_COAGULATION                            0.990625  0.034849
# HALLMARK_COMPLEMENT                             0.620156  0.001314
# HALLMARK_DNA_REPAIR                             0.000000  0.001314
# HALLMARK_E2F_TARGETS                            0.000000  0.001314
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION      0.990625  0.969031
# HALLMARK_ESTROGEN_RESPONSE_EARLY                0.990625  0.002562
# HALLMARK_ESTROGEN_RESPONSE_LATE                 0.990625  0.006244
# HALLMARK_FATTY_ACID_METABOLISM                  0.000000  0.001314
# HALLMARK_G2M_CHECKPOINT                         0.000000  0.001314
# HALLMARK_GLYCOLYSIS                             0.905479  0.001314
# HALLMARK_HEDGEHOG_SIGNALING                     0.990625  0.969031
# HALLMARK_HEME_METABOLISM                        0.905479  0.001314
# HALLMARK_HYPOXIA                                0.950303  0.001314
# HALLMARK_IL2_STAT5_SIGNALING                    1.000000  0.001314
# HALLMARK_IL6_JAK_STAT3_SIGNALING                0.000000  0.001314
# HALLMARK_INFLAMMATORY_RESPONSE                  0.000000  0.001314
# HALLMARK_INTERFERON_ALPHA_RESPONSE              0.000000  0.001314
# HALLMARK_INTERFERON_GAMMA_RESPONSE              0.000000  0.001314
# HALLMARK_KRAS_SIGNALING_DN                      0.950303  0.889328
# HALLMARK_KRAS_SIGNALING_UP                      0.990625  0.001314
# HALLMARK_MITOTIC_SPINDLE                        0.000000  0.001314
# HALLMARK_MTORC1_SIGNALING                       0.000000  0.001314
# HALLMARK_MYC_TARGETS_V1                         0.000000  0.001314
# HALLMARK_MYC_TARGETS_V2                         0.000000  0.001314
# HALLMARK_MYOGENESIS                             0.990625  0.705961
# HALLMARK_NOTCH_SIGNALING                        0.000000  0.001314
# HALLMARK_OXIDATIVE_PHOSPHORYLATION              0.000000  0.001314
# HALLMARK_P53_PATHWAY                            0.000000  0.001314
# HALLMARK_PANCREAS_BETA_CELLS                    0.990625  0.969031
# HALLMARK_PEROXISOME                             0.000000  0.001314
# HALLMARK_PI3K_AKT_MTOR_SIGNALING                0.000000  0.001314
# HALLMARK_PROTEIN_SECRETION                      0.000000  0.001314
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        0.000000  0.001314
# HALLMARK_SPERMATOGENESIS                        0.950303  0.009746
# HALLMARK_TGF_BETA_SIGNALING                     0.000000  0.001314
# HALLMARK_TNFA_SIGNALING_VIA_NFKB                0.000000  0.001314
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE              0.000000  0.001314
# HALLMARK_UV_RESPONSE_DN                         0.000000  0.001314
# HALLMARK_UV_RESPONSE_UP                         0.000000  0.001314
# HALLMARK_WNT_BETA_CATENIN_SIGNALING             0.990625  0.001314
# HALLMARK_XENOBIOTIC_METABOLISM                  0.950303  0.001314
