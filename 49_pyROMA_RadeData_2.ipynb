# %%
import scanpy as sc
import time
from pyROMA.ROMA import *
import os
import pandas as pd
import anndata
print(os.getcwd())
print(ROMA)
# Out:
# /home/az/Projects/01_Curie/05_pyROMA/pyROMA_shared
# <class 'pyROMA.ROMA.ROMA'>

# %%
# Initialize ROMA
roma = ROMA()
# this should be empty at first
roma.adata

# %%
roma
# Out:
# scROMA

# %%
df = pd.read_csv('/home/az/Projects/01_Curie/06.1_pyROMA_Sofia_results/pbulk_matrix_Rade2024_normalized.csv',index_col=0)
print(df.shape)
df.head()
# Out:
# (36602, 177)
#              MXMERZ002A_02_clusterCD4 T-Cell  MXMERZ002A_02_clusterCD8 T-Cell  \
# CAR-BCMA                           -0.734156                        -0.734156
# MIR1302-2HG                        -0.734156                        -0.734156
# FAM138A                            -0.734156                        -0.734156
# OR4F5                              -0.734156                        -0.734156
# AL627309.1                         -0.734156                        -0.734156
#
#              MXMERZ002A_02_clustercDC  MXMERZ002A_02_clusterMono CD14  \
# CAR-BCMA                    -0.734156                       -0.734156
# MIR1302-2HG                 -0.734156                       -0.052713
# FAM138A                     -0.734156                       -0.734156
# OR4F5                       -0.734156                       -0.734156
# AL627309.1                  -0.734156                       -0.052713
#
#              MXMERZ002A_02_clusterMono CD16  MXMERZ002A_02_clusterNK  \
# CAR-BCMA                          -0.734156                -0.734156
# MIR1302-2HG                       -0.734156                -0.734156
# FAM138A                           -0.734156                -0.734156
# OR4F5                             -0.734156                -0.734156
# AL627309.1                        -0.734156                -0.734156
#
#              MXMERZ002A_02_clusterpDC  MXMERZ002A_02_clusterPlasma cell  \
# CAR-BCMA                    -0.734156                         -0.734156
# MIR1302-2HG                 -0.734156                         -0.734156
# FAM138A                     -0.734156                         -0.734156
# OR4F5                       -0.734156                         -0.734156
# AL627309.1                  -0.734156                         -0.230462
#
#              MXMERZ002A_02_clusterProgenitor  MXMERZ002A_03_clusterB-Cell  \
# CAR-BCMA                           -0.734156                    -0.734156
# MIR1302-2HG                        -0.734156                    -0.734156
# FAM138A                            -0.734156                    -0.734156
# OR4F5                              -0.734156                    -0.734156
# AL627309.1                         -0.734156                     0.829174
#
#              ...  MXMERZ002A_24_clusterPlasma cell  \
# CAR-BCMA     ...                         -0.734156
# MIR1302-2HG  ...                         -0.734156
# FAM138A      ...                         -0.734156
# OR4F5        ...                         -0.734156
# AL627309.1   ...                         -0.734156
#
#              MXMERZ002A_24_clusterProgenitor  MXMERZ002A_25_clusterB-Cell  \
# CAR-BCMA                           -0.734156                    -0.734156
# MIR1302-2HG                        -0.734156                    -0.734156
# FAM138A                            -0.734156                    -0.734156
# OR4F5                              -0.734156                    -0.734156
# AL627309.1                         -0.734156                    -0.734156
#
#              MXMERZ002A_25_clusterCD4 T-Cell  MXMERZ002A_25_clusterCD8 T-Cell  \
# CAR-BCMA                           -0.734156                        -0.734156
# MIR1302-2HG                        -0.734156                        -0.734156
# FAM138A                            -0.734156                        -0.734156
# OR4F5                              -0.734156                        -0.734156
# AL627309.1                         -0.734156                        -0.734156
#
#              MXMERZ002A_25_clustercDC  MXMERZ002A_25_clusterMono CD14  \
# CAR-BCMA                    -0.734156                       -0.734156
# MIR1302-2HG                 -0.734156                       -0.734156
# FAM138A                     -0.734156                       -0.734156
# OR4F5                       -0.734156                       -0.734156
# AL627309.1                  -0.734156                        2.151458
#
#              MXMERZ002A_25_clusterMono CD16  MXMERZ002A_25_clusterNK  \
# CAR-BCMA                          -0.734156                -0.734156
# MIR1302-2HG                       -0.734156                -0.734156
# FAM138A                           -0.734156                -0.734156
# OR4F5                             -0.734156                -0.734156
# AL627309.1                        -0.734156                -0.734156
#
#              MXMERZ002A_25_clusterpDC
# CAR-BCMA                    -0.734156
# MIR1302-2HG                 -0.734156
# FAM138A                     -0.734156
# OR4F5                       -0.734156
# AL627309.1                  -0.734156
#
# [5 rows x 177 columns]

# %%
adata = anndata.AnnData(df.T)
adata
# Out:
# AnnData object with n_obs × n_vars = 177 × 36602

# %%
# Genes are in the var
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [CAR-BCMA, MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3, AL627309.2, AL627309.5, AL627309.4, AP006222.2, AL732372.1, OR4F29, AC114498.1, OR4F16, AL669831.2, LINC01409, FAM87B, LINC01128, LINC00115, FAM41C, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.1, AGRN, AL645608.5, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, AL139287.1, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20-AS1, MRPL20, AL391244.2, ANKRD65, AL391244.1, TMEM88B, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.4, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, ...]
#
# [36602 rows x 0 columns]

# %%
roma.adata = adata
print(roma.adata)
# Out:
# AnnData object with n_obs × n_vars = 177 × 36602

# %%
os.chdir('/home/az/Projects/01_Curie/06.1_pyROMA_Sofia_results/')
roma.gmt ='h.all.v2023.2.Hs.symbols.gmt'
# This function allows to load the patwhays into dictionary
pathways = roma.read_gmt_to_dict('h.all.v2023.2.Hs.symbols.gmt')

# %%
pathways_to_check = 'all'

# %%
roma
# Out:
# scROMA

# %%
# Filter pathways that have less genes than min_n_number
roma.min_n_genes
# Out:
# 10

# %%
# Set the number of iterations to create the null distribution
iters = 1000

# %%
start = time.time()
# run it without outlier detection
roma.compute(pathways_to_check, parallel=True, incremental=True, iters=iters, loocv_on=False)
end = time.time()
minutes, seconds = divmod(end - start, 60)
print(f"Incremental Parallel {iters} iterations, running time (min): " + "{:0>2}:{:05.2f}".format(int(minutes),seconds))

adata
# Out:
# Processing gene set: HALLMARK_NOTCH_SIGNALING | len of subsetlist:  32
# Processing gene set: HALLMARK_ANGIOGENESIS | len of subsetlist:  36
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_HEDGEHOG_SIGNALING | len of subsetlist:  36
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_PANCREAS_BETA_CELLS | len of subsetlist:  40
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_WNT_BETA_CATENIN_SIGNALING | len of subsetlist:  42
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_APICAL_SURFACE | len of subsetlist:  44
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY | len of subsetlist:  49
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_TGF_BETA_SIGNALING | len of subsetlist:  54
# Processing gene set: HALLMARK_MYC_TARGETS_V2 | len of subsetlist:  57
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_CHOLESTEROL_HOMEOSTASIS | len of subsetlist:  74
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_IL6_JAK_STAT3_SIGNALING | len of subsetlist:  87
# Processing gene set: HALLMARK_PROTEIN_SECRETION | len of subsetlist:  96
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_INTERFERON_ALPHA_RESPONSE | len of subsetlist:  96
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ANDROGEN_RESPONSE | len of subsetlist:  99
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_PEROXISOME | len of subsetlist:  104
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_PI3K_AKT_MTOR_SIGNALING | len of subsetlist:  105
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_BILE_ACID_METABOLISM | len of subsetlist:  112
# Processing gene set: HALLMARK_UNFOLDED_PROTEIN_RESPONSE | len of subsetlist:  109
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_SPERMATOGENESIS | len of subsetlist:  134
# Processing gene set: HALLMARK_COAGULATION | len of subsetlist:  138
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_UV_RESPONSE_DN | len of subsetlist:  144
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_DNA_REPAIR | len of subsetlist:  149
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_FATTY_ACID_METABOLISM | len of subsetlist:  156
# Processing gene set: HALLMARK_UV_RESPONSE_UP | len of subsetlist:  156
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_APOPTOSIS | len of subsetlist:  159
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_IL2_STAT5_SIGNALING | len of subsetlist:  198
# Processing gene set: HALLMARK_MITOTIC_SPINDLE | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ADIPOGENESIS | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ALLOGRAFT_REJECTION | len of subsetlist:  196
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_APICAL_JUNCTION | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_COMPLEMENT | len of subsetlist:  200
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_E2F_TARGETS | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION | len of subsetlist:  200
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ESTROGEN_RESPONSE_EARLY | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_ESTROGEN_RESPONSE_LATE | len of subsetlist:  197
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_G2M_CHECKPOINT | len of subsetlist:  195
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_GLYCOLYSIS | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_HEME_METABOLISM | len of subsetlist:  194
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_HYPOXIA | len of subsetlist:  200
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_INFLAMMATORY_RESPONSE | len of subsetlist:  200
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_INTERFERON_GAMMA_RESPONSE | len of subsetlist:  197
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_KRAS_SIGNALING_DN | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_KRAS_SIGNALING_UP | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_MTORC1_SIGNALING | len of subsetlist:  197
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_MYC_TARGETS_V1 | len of subsetlist:  195
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_MYOGENESIS | len of subsetlist:  198
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_OXIDATIVE_PHOSPHORYLATION | len of subsetlist:  200
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_P53_PATHWAY | len of subsetlist:  196
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_TNFA_SIGNALING_VIA_NFKB | len of subsetlist:  199
# Took null distribution from previous calculation
# Processing gene set: HALLMARK_XENOBIOTIC_METABOLISM | len of subsetlist:  196
# Took null distribution from previous calculation
#   Finished : Icnremental Parallel 1000 iterations, running time (min): 03:18.74
# AnnData object with n_obs × n_vars = 177 × 36602
#     uns: 'ROMA', 'ROMA_stats', 'ROMA_active_modules'

# %%
roma
# Out:
# scROMA: module activities are computed

# %%
roma.adata
# Out:
# AnnData object with n_obs × n_vars = 177 × 36602
#     uns: 'ROMA', 'ROMA_stats', 'ROMA_active_modules'

# %%
roma.adata.uns['ROMA_stats']
# Out:
#                                                   L1   p_value  Median_Exp  \
# HALLMARK_NOTCH_SIGNALING                    0.382555  0.462963    0.261270
# HALLMARK_ANGIOGENESIS                       0.374468  0.462963   -1.339803
# HALLMARK_HEDGEHOG_SIGNALING                 0.290006  0.666667   -2.193817
# HALLMARK_PANCREAS_BETA_CELLS                0.402495  0.462963    2.072513
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         0.280357  0.666667    0.142385
# HALLMARK_APICAL_SURFACE                     0.362655  0.462963    2.086943
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY    0.362250  0.462963    1.996279
# HALLMARK_TGF_BETA_SIGNALING                 0.334185  0.666667    0.942344
# HALLMARK_MYC_TARGETS_V2                     0.427706  0.462963    2.060324
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            0.301363  0.666667   -2.146313
# HALLMARK_IL6_JAK_STAT3_SIGNALING            0.345576  0.462963    2.353663
# HALLMARK_PROTEIN_SECRETION                  0.421360  0.462963    3.115352
# HALLMARK_INTERFERON_ALPHA_RESPONSE          0.460176  0.462963    4.020584
# HALLMARK_ANDROGEN_RESPONSE                  0.274107  0.462963   -2.985747
# HALLMARK_PEROXISOME                         0.334484  0.462963    3.278511
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            0.353041  0.462963    3.331131
# HALLMARK_BILE_ACID_METABOLISM               0.251557  0.666667   -1.640059
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          0.388575  0.462963    2.982996
# HALLMARK_SPERMATOGENESIS                    0.269351  0.666667   -0.909284
# HALLMARK_COAGULATION                        0.318418  0.462963   -2.727724
# HALLMARK_UV_RESPONSE_DN                     0.266784  0.666667    3.384940
# HALLMARK_DNA_REPAIR                         0.405204  0.462963    3.808544
# HALLMARK_FATTY_ACID_METABOLISM              0.337609  0.462963    3.704759
# HALLMARK_UV_RESPONSE_UP                     0.324626  0.462963   -2.547814
# HALLMARK_APOPTOSIS                          0.287325  0.666667    4.218848
# HALLMARK_IL2_STAT5_SIGNALING                0.237890  0.666667    3.637030
# HALLMARK_MITOTIC_SPINDLE                    0.314834  0.462963    4.400750
# HALLMARK_ADIPOGENESIS                       0.368238  0.462963    3.399110
# HALLMARK_ALLOGRAFT_REJECTION                0.348063  0.462963    9.028732
# HALLMARK_APICAL_JUNCTION                    0.295964  0.462963    0.487609
# HALLMARK_COMPLEMENT                         0.336327  0.462963   -3.396814
# HALLMARK_E2F_TARGETS                        0.386313  0.462963    0.668640
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.259521  0.666667    3.770283
# HALLMARK_ESTROGEN_RESPONSE_EARLY            0.231468  0.666667    3.859260
# HALLMARK_ESTROGEN_RESPONSE_LATE             0.251739  0.666667    2.947792
# HALLMARK_G2M_CHECKPOINT                     0.336723  0.462963   -0.827051
# HALLMARK_GLYCOLYSIS                         0.292909  0.462963   -3.984655
# HALLMARK_HEME_METABOLISM                    0.286127  0.462963    3.940551
# HALLMARK_HYPOXIA                            0.295565  0.462963   -1.535865
# HALLMARK_INFLAMMATORY_RESPONSE              0.337921  0.462963   -6.001224
# HALLMARK_INTERFERON_GAMMA_RESPONSE          0.350773  0.462963    4.938466
# HALLMARK_KRAS_SIGNALING_DN                  0.209949  0.666667   -2.503399
# HALLMARK_KRAS_SIGNALING_UP                  0.306119  0.462963    3.818345
# HALLMARK_MTORC1_SIGNALING                   0.356976  0.462963    5.236343
# HALLMARK_MYC_TARGETS_V1                     0.462690  0.462963    4.207935
# HALLMARK_MYOGENESIS                         0.229624  0.666667   -2.712139
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.488264  0.462963    4.913145
# HALLMARK_P53_PATHWAY                        0.303113  0.462963   -4.574919
# HALLMARK_TNFA_SIGNALING_VIA_NFKB            0.339077  0.462963    0.498156
# HALLMARK_XENOBIOTIC_METABOLISM              0.311517  0.462963    0.011393
#
#                                              q_value
# HALLMARK_NOTCH_SIGNALING                    0.389888
# HALLMARK_ANGIOGENESIS                       1.000000
# HALLMARK_HEDGEHOG_SIGNALING                 1.000000
# HALLMARK_PANCREAS_BETA_CELLS                0.002172
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         0.399600
# HALLMARK_APICAL_SURFACE                     0.002172
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY    0.002172
# HALLMARK_TGF_BETA_SIGNALING                 0.246896
# HALLMARK_MYC_TARGETS_V2                     0.005763
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            1.000000
# HALLMARK_IL6_JAK_STAT3_SIGNALING            0.005763
# HALLMARK_PROTEIN_SECRETION                  0.002172
# HALLMARK_INTERFERON_ALPHA_RESPONSE          0.002172
# HALLMARK_ANDROGEN_RESPONSE                  1.000000
# HALLMARK_PEROXISOME                         0.002172
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            0.002172
# HALLMARK_BILE_ACID_METABOLISM               0.470582
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          0.002172
# HALLMARK_SPERMATOGENESIS                    0.232121
# HALLMARK_COAGULATION                        1.000000
# HALLMARK_UV_RESPONSE_DN                     0.002172
# HALLMARK_DNA_REPAIR                         0.002172
# HALLMARK_FATTY_ACID_METABOLISM              0.002172
# HALLMARK_UV_RESPONSE_UP                     1.000000
# HALLMARK_APOPTOSIS                          0.002172
# HALLMARK_IL2_STAT5_SIGNALING                0.002172
# HALLMARK_MITOTIC_SPINDLE                    0.002172
# HALLMARK_ADIPOGENESIS                       0.004163
# HALLMARK_ALLOGRAFT_REJECTION                0.002172
# HALLMARK_APICAL_JUNCTION                    0.132126
# HALLMARK_COMPLEMENT                         1.000000
# HALLMARK_E2F_TARGETS                        0.132126
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.002172
# HALLMARK_ESTROGEN_RESPONSE_EARLY            0.002172
# HALLMARK_ESTROGEN_RESPONSE_LATE             0.022200
# HALLMARK_G2M_CHECKPOINT                     0.138924
# HALLMARK_GLYCOLYSIS                         1.000000
# HALLMARK_HEME_METABOLISM                    0.002172
# HALLMARK_HYPOXIA                            0.196773
# HALLMARK_INFLAMMATORY_RESPONSE              1.000000
# HALLMARK_INTERFERON_GAMMA_RESPONSE          0.002172
# HALLMARK_KRAS_SIGNALING_DN                  0.562258
# HALLMARK_KRAS_SIGNALING_UP                  0.002172
# HALLMARK_MTORC1_SIGNALING                   0.002172
# HALLMARK_MYC_TARGETS_V1                     0.002172
# HALLMARK_MYOGENESIS                         0.852897
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.002172
# HALLMARK_P53_PATHWAY                        1.000000
# HALLMARK_TNFA_SIGNALING_VIA_NFKB            0.132126
# HALLMARK_XENOBIOTIC_METABOLISM              0.132126

# %%
type(roma.adata)
# Out:
# anndata._core.anndata.AnnData

# %%
type(adata.uns['ROMA'])
# Out:
# dict

# %%
type(adata.uns['ROMA_stats'])
# Out:
# pandas.core.frame.DataFrame

# %%
def save_ROMA_results(adata, path):
    # saves the adata to a path
    import pickle 
    d = adata.uns['ROMA']

    with open(f'{path}.pickle', 'wb') as handle:
        pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)

    del adata.uns['ROMA']
    adata.write(f"{path}.h5ad")

    return

def load_ROMA_results(path):
    # loads the results into adata
    import pickle
    import scanpy as sc 

    with open(f'{path}.pickle', 'rb') as handle:
        d = pickle.load(handle)

    adata = sc.read_h5ad(f'{path}.h5ad')
    adata.uns['ROMA'] = d

    return adata

# %%
adata_backup = roma.adata.copy()

# %%
path_to_save = '/home/az/Projects/01_Curie/06.1_pyROMA_Sofia_results/pyroma_outputs/RadeData_incremental'
save_ROMA_results(adata=roma.adata, path=path_to_save)

# %%
del roma.adata

# %%
roma.adata
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 roma.adata
#
# AttributeError: 'ROMA' object has no attribute 'adata'

# %%
roma.adata = load_ROMA_results(path_to_save)

# %%
roma.adata
# Out:
# AnnData object with n_obs × n_vars = 177 × 36602
#     uns: 'ROMA_active_modules', 'ROMA_stats', 'ROMA'

# %%
roma.adata.uns['ROMA_stats'].to_csv('pyroma_outputs/ROMA_stats_incremental.csv')

# %% [markdown]
# # Compare rROMA and pyROMA

# %%
rROMA_df = pd.read_csv('/home/az/Projects/01_Curie/06.1_pyROMA_Sofia_results/roma_outputs/RadeData_module_matrix.csv', index_col=[0])
rROMA_df.head()
# Out:
#                                     L1  Median L1  ppv L1     L1/L2  \
# HALLMARK_ADIPOGENESIS         0.129883   0.198628    1.00  0.974184
# HALLMARK_ALLOGRAFT_REJECTION  0.390254   0.198628    0.00  4.241984
# HALLMARK_ANDROGEN_RESPONSE    0.115085   0.211010    1.00  1.017066
# HALLMARK_ANGIOGENESIS         0.296008   0.260650    0.24  1.338702
# HALLMARK_APICAL_JUNCTION      0.234288   0.198628    0.01  1.688134
#
#                               Median L1/L2  ppv L1/L2  Median Exp  \
# HALLMARK_ADIPOGENESIS             1.425571       1.00    9.257435
# HALLMARK_ALLOGRAFT_REJECTION      1.425571       0.00   -0.769921
# HALLMARK_ANDROGEN_RESPONSE        1.449478       1.00   -6.831589
# HALLMARK_ANGIOGENESIS             1.640605       0.76   -0.154860
# HALLMARK_APICAL_JUNCTION          1.425571       0.22   -0.423093
#
#                               ppv Median Exp      q L1   q L1/L2  q Median Exp
# HALLMARK_ADIPOGENESIS                   0.00  1.000000  1.000000      0.000000
# HALLMARK_ALLOGRAFT_REJECTION            0.98  0.000000  0.000000      0.990625
# HALLMARK_ANDROGEN_RESPONSE              0.00  1.000000  1.000000      0.000000
# HALLMARK_ANGIOGENESIS                   0.96  0.666667  1.000000      0.990625
# HALLMARK_APICAL_JUNCTION                0.99  0.041667  0.676471      0.990625

# %%
pyroma = roma.adata.uns['ROMA_stats'].copy()
pyroma.head()
# Out:
#                                            L1   p_value  Median_Exp   q_value
# HALLMARK_NOTCH_SIGNALING             0.382555  0.462963    0.261270  0.389888
# HALLMARK_ANGIOGENESIS                0.374468  0.462963   -1.339803  1.000000
# HALLMARK_HEDGEHOG_SIGNALING          0.290006  0.666667   -2.193817  1.000000
# HALLMARK_PANCREAS_BETA_CELLS         0.402495  0.462963    2.072513  0.002172
# HALLMARK_WNT_BETA_CATENIN_SIGNALING  0.280357  0.666667    0.142385  0.399600

# %%
# Extract Median Exp L1

# %%
rROMA_df.shape
# Out:
# (50, 11)

# %%
pyroma.shape
# Out:
# (50, 4)

# %%
merged_df = pd.merge(rROMA_df, pyroma, left_index=True, right_index=True, suffixes=('_R', '_py'))
merged_df.head()
# Out:
#                                   L1_R  Median L1  ppv L1     L1/L2  \
# HALLMARK_ADIPOGENESIS         0.129883   0.198628    1.00  0.974184
# HALLMARK_ALLOGRAFT_REJECTION  0.390254   0.198628    0.00  4.241984
# HALLMARK_ANDROGEN_RESPONSE    0.115085   0.211010    1.00  1.017066
# HALLMARK_ANGIOGENESIS         0.296008   0.260650    0.24  1.338702
# HALLMARK_APICAL_JUNCTION      0.234288   0.198628    0.01  1.688134
#
#                               Median L1/L2  ppv L1/L2  Median Exp  \
# HALLMARK_ADIPOGENESIS             1.425571       1.00    9.257435
# HALLMARK_ALLOGRAFT_REJECTION      1.425571       0.00   -0.769921
# HALLMARK_ANDROGEN_RESPONSE        1.449478       1.00   -6.831589
# HALLMARK_ANGIOGENESIS             1.640605       0.76   -0.154860
# HALLMARK_APICAL_JUNCTION          1.425571       0.22   -0.423093
#
#                               ppv Median Exp      q L1   q L1/L2  \
# HALLMARK_ADIPOGENESIS                   0.00  1.000000  1.000000
# HALLMARK_ALLOGRAFT_REJECTION            0.98  0.000000  0.000000
# HALLMARK_ANDROGEN_RESPONSE              0.00  1.000000  1.000000
# HALLMARK_ANGIOGENESIS                   0.96  0.666667  1.000000
# HALLMARK_APICAL_JUNCTION                0.99  0.041667  0.676471
#
#                               q Median Exp     L1_py   p_value  Median_Exp  \
# HALLMARK_ADIPOGENESIS             0.000000  0.368238  0.462963    3.399110
# HALLMARK_ALLOGRAFT_REJECTION      0.990625  0.348063  0.462963    9.028732
# HALLMARK_ANDROGEN_RESPONSE        0.000000  0.274107  0.462963   -2.985747
# HALLMARK_ANGIOGENESIS             0.990625  0.374468  0.462963   -1.339803
# HALLMARK_APICAL_JUNCTION          0.990625  0.295964  0.462963    0.487609
#
#                                q_value
# HALLMARK_ADIPOGENESIS         0.004163
# HALLMARK_ALLOGRAFT_REJECTION  0.002172
# HALLMARK_ANDROGEN_RESPONSE    1.000000
# HALLMARK_ANGIOGENESIS         1.000000
# HALLMARK_APICAL_JUNCTION      0.132126

# %%
merged_df.shape
# Out:
# (50, 15)

# %%
merged_df[['L1_R', 'L1_py', 'ppv L1','p_value', 'Median Exp', 'Median_Exp','q Median Exp', 'q_value' ]]
# Out:
#                                                 L1_R     L1_py  ppv L1  \
# HALLMARK_ADIPOGENESIS                       0.129883  0.368238    1.00
# HALLMARK_ALLOGRAFT_REJECTION                0.390254  0.348063    0.00
# HALLMARK_ANDROGEN_RESPONSE                  0.115085  0.274107    1.00
# HALLMARK_ANGIOGENESIS                       0.296008  0.374468    0.24
# HALLMARK_APICAL_JUNCTION                    0.234288  0.295964    0.01
# HALLMARK_APICAL_SURFACE                     0.410351  0.362655    0.00
# HALLMARK_APOPTOSIS                          0.212387  0.287325    0.24
# HALLMARK_BILE_ACID_METABOLISM               0.209202  0.251557    0.46
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            0.156816  0.301363    0.99
# HALLMARK_COAGULATION                        0.262133  0.318418    0.01
# HALLMARK_COMPLEMENT                         0.311857  0.336327    0.00
# HALLMARK_DNA_REPAIR                         0.054802  0.405204    1.00
# HALLMARK_E2F_TARGETS                        0.052095  0.386313    1.00
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.247274  0.259521    0.00
# HALLMARK_ESTROGEN_RESPONSE_EARLY            0.247689  0.231468    0.00
# HALLMARK_ESTROGEN_RESPONSE_LATE             0.244319  0.251739    0.00
# HALLMARK_FATTY_ACID_METABOLISM              0.113011  0.337609    1.00
# HALLMARK_G2M_CHECKPOINT                     0.079111  0.336723    1.00
# HALLMARK_GLYCOLYSIS                         0.165898  0.292909    1.00
# HALLMARK_HEDGEHOG_SIGNALING                 0.300483  0.290006    0.20
# HALLMARK_HEME_METABOLISM                    0.167447  0.286127    1.00
# HALLMARK_HYPOXIA                            0.206203  0.295565    0.31
# HALLMARK_IL2_STAT5_SIGNALING                0.254344  0.237890    0.00
# HALLMARK_IL6_JAK_STAT3_SIGNALING            0.257806  0.345576    0.07
# HALLMARK_INFLAMMATORY_RESPONSE              0.303830  0.337921    0.00
# HALLMARK_INTERFERON_ALPHA_RESPONSE          0.113747  0.460176    1.00
# HALLMARK_INTERFERON_GAMMA_RESPONSE          0.115875  0.350773    1.00
# HALLMARK_KRAS_SIGNALING_DN                  0.175279  0.209949    0.95
# HALLMARK_KRAS_SIGNALING_UP                  0.270726  0.306119    0.00
# HALLMARK_MITOTIC_SPINDLE                    0.069785  0.314834    1.00
# HALLMARK_MTORC1_SIGNALING                   0.071542  0.356976    1.00
# HALLMARK_MYC_TARGETS_V1                     0.055770  0.462690    1.00
# HALLMARK_MYC_TARGETS_V2                     0.044532  0.427706    1.00
# HALLMARK_MYOGENESIS                         0.213694  0.229624    0.16
# HALLMARK_NOTCH_SIGNALING                    0.208068  0.382555    0.95
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.048424  0.488264    1.00
# HALLMARK_P53_PATHWAY                        0.163679  0.303113    1.00
# HALLMARK_PANCREAS_BETA_CELLS                0.418310  0.402495    0.00
# HALLMARK_PEROXISOME                         0.121004  0.334484    1.00
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            0.088799  0.353041    1.00
# HALLMARK_PROTEIN_SECRETION                  0.093887  0.421360    1.00
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY    0.043703  0.362250    1.00
# HALLMARK_SPERMATOGENESIS                    0.173877  0.269351    0.95
# HALLMARK_TGF_BETA_SIGNALING                 0.140248  0.334185    1.00
# HALLMARK_TNFA_SIGNALING_VIA_NFKB            0.166778  0.339077    1.00
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          0.069121  0.388575    1.00
# HALLMARK_UV_RESPONSE_DN                     0.155753  0.266784    1.00
# HALLMARK_UV_RESPONSE_UP                     0.179762  0.324626    0.88
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         0.293957  0.280357    0.24
# HALLMARK_XENOBIOTIC_METABOLISM              0.209181  0.311517    0.28
#
#                                              p_value  Median Exp  Median_Exp  \
# HALLMARK_ADIPOGENESIS                       0.462963    9.257435    3.399110
# HALLMARK_ALLOGRAFT_REJECTION                0.462963   -0.769921    9.028732
# HALLMARK_ANDROGEN_RESPONSE                  0.462963   -6.831589   -2.985747
# HALLMARK_ANGIOGENESIS                       0.462963   -0.154860   -1.339803
# HALLMARK_APICAL_JUNCTION                    0.462963   -0.423093    0.487609
# HALLMARK_APICAL_SURFACE                     0.462963   -0.191439    2.086943
# HALLMARK_APOPTOSIS                          0.666667    3.690577    4.218848
# HALLMARK_BILE_ACID_METABOLISM               0.666667    0.318406   -1.640059
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            0.666667   -5.151147   -2.146313
# HALLMARK_COAGULATION                        0.462963   -0.600306   -2.727724
# HALLMARK_COMPLEMENT                         0.462963   -3.590742   -3.396814
# HALLMARK_DNA_REPAIR                         0.462963   -9.966074    3.808544
# HALLMARK_E2F_TARGETS                        0.462963    9.450042    0.668640
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.666667   -0.991621    3.770283
# HALLMARK_ESTROGEN_RESPONSE_EARLY            0.666667   -0.330045    3.859260
# HALLMARK_ESTROGEN_RESPONSE_LATE             0.666667   -0.767386    2.947792
# HALLMARK_FATTY_ACID_METABOLISM              0.462963    8.024034    3.704759
# HALLMARK_G2M_CHECKPOINT                     0.462963   -8.325046   -0.827051
# HALLMARK_GLYCOLYSIS                         0.462963   -3.161271   -3.984655
# HALLMARK_HEDGEHOG_SIGNALING                 0.666667   -0.774146   -2.193817
# HALLMARK_HEME_METABOLISM                    0.462963    3.111260    3.940551
# HALLMARK_HYPOXIA                            0.462963   -2.789599   -1.535865
# HALLMARK_IL2_STAT5_SIGNALING                0.666667    0.079694    3.637030
# HALLMARK_IL6_JAK_STAT3_SIGNALING            0.462963    6.547266    2.353663
# HALLMARK_INFLAMMATORY_RESPONSE              0.462963    4.757414   -6.001224
# HALLMARK_INTERFERON_ALPHA_RESPONSE          0.462963   13.594840    4.020584
# HALLMARK_INTERFERON_GAMMA_RESPONSE          0.462963   11.428728    4.938466
# HALLMARK_KRAS_SIGNALING_DN                  0.666667    2.731300   -2.503399
# HALLMARK_KRAS_SIGNALING_UP                  0.462963    0.209971    3.818345
# HALLMARK_MITOTIC_SPINDLE                    0.462963    7.721097    4.400750
# HALLMARK_MTORC1_SIGNALING                   0.462963  -10.271260    5.236343
# HALLMARK_MYC_TARGETS_V1                     0.462963  -11.083112    4.207935
# HALLMARK_MYC_TARGETS_V2                     0.462963   10.608229    2.060324
# HALLMARK_MYOGENESIS                         0.666667    1.085115   -2.712139
# HALLMARK_NOTCH_SIGNALING                    0.462963   -6.026655    0.261270
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.462963  -11.410719    4.913145
# HALLMARK_P53_PATHWAY                        0.462963    5.118835   -4.574919
# HALLMARK_PANCREAS_BETA_CELLS                0.462963    0.481904    2.072513
# HALLMARK_PEROXISOME                         0.462963    8.007085    3.278511
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            0.462963    9.183649    3.331131
# HALLMARK_PROTEIN_SECRETION                  0.462963   10.900896    3.115352
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY    0.462963   10.828462    1.996279
# HALLMARK_SPERMATOGENESIS                    0.666667    1.692436   -0.909284
# HALLMARK_TGF_BETA_SIGNALING                 0.666667   10.231111    0.942344
# HALLMARK_TNFA_SIGNALING_VIA_NFKB            0.462963    8.625433    0.498156
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          0.462963   10.216817    2.982996
# HALLMARK_UV_RESPONSE_DN                     0.666667   -4.328813    3.384940
# HALLMARK_UV_RESPONSE_UP                     0.462963    5.846261   -2.547814
# HALLMARK_WNT_BETA_CATENIN_SIGNALING         0.666667    0.079378    0.142385
# HALLMARK_XENOBIOTIC_METABOLISM              0.462963   -2.744293    0.011393
#
#                                             q Median Exp   q_value
# HALLMARK_ADIPOGENESIS                           0.000000  0.004163
# HALLMARK_ALLOGRAFT_REJECTION                    0.990625  0.002172
# HALLMARK_ANDROGEN_RESPONSE                      0.000000  1.000000
# HALLMARK_ANGIOGENESIS                           0.990625  1.000000
# HALLMARK_APICAL_JUNCTION                        0.990625  0.132126
# HALLMARK_APICAL_SURFACE                         0.990625  0.002172
# HALLMARK_APOPTOSIS                              0.546713  0.002172
# HALLMARK_BILE_ACID_METABOLISM                   0.990625  0.470582
# HALLMARK_CHOLESTEROL_HOMEOSTASIS                0.000000  1.000000
# HALLMARK_COAGULATION                            0.990625  1.000000
# HALLMARK_COMPLEMENT                             0.620156  1.000000
# HALLMARK_DNA_REPAIR                             0.000000  0.002172
# HALLMARK_E2F_TARGETS                            0.000000  0.132126
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION      0.990625  0.002172
# HALLMARK_ESTROGEN_RESPONSE_EARLY                0.990625  0.002172
# HALLMARK_ESTROGEN_RESPONSE_LATE                 0.990625  0.022200
# HALLMARK_FATTY_ACID_METABOLISM                  0.000000  0.002172
# HALLMARK_G2M_CHECKPOINT                         0.000000  0.138924
# HALLMARK_GLYCOLYSIS                             0.905479  1.000000
# HALLMARK_HEDGEHOG_SIGNALING                     0.990625  1.000000
# HALLMARK_HEME_METABOLISM                        0.905479  0.002172
# HALLMARK_HYPOXIA                                0.950303  0.196773
# HALLMARK_IL2_STAT5_SIGNALING                    1.000000  0.002172
# HALLMARK_IL6_JAK_STAT3_SIGNALING                0.000000  0.005763
# HALLMARK_INFLAMMATORY_RESPONSE                  0.000000  1.000000
# HALLMARK_INTERFERON_ALPHA_RESPONSE              0.000000  0.002172
# HALLMARK_INTERFERON_GAMMA_RESPONSE              0.000000  0.002172
# HALLMARK_KRAS_SIGNALING_DN                      0.950303  0.562258
# HALLMARK_KRAS_SIGNALING_UP                      0.990625  0.002172
# HALLMARK_MITOTIC_SPINDLE                        0.000000  0.002172
# HALLMARK_MTORC1_SIGNALING                       0.000000  0.002172
# HALLMARK_MYC_TARGETS_V1                         0.000000  0.002172
# HALLMARK_MYC_TARGETS_V2                         0.000000  0.005763
# HALLMARK_MYOGENESIS                             0.990625  0.852897
# HALLMARK_NOTCH_SIGNALING                        0.000000  0.389888
# HALLMARK_OXIDATIVE_PHOSPHORYLATION              0.000000  0.002172
# HALLMARK_P53_PATHWAY                            0.000000  1.000000
# HALLMARK_PANCREAS_BETA_CELLS                    0.990625  0.002172
# HALLMARK_PEROXISOME                             0.000000  0.002172
# HALLMARK_PI3K_AKT_MTOR_SIGNALING                0.000000  0.002172
# HALLMARK_PROTEIN_SECRETION                      0.000000  0.002172
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY        0.000000  0.002172
# HALLMARK_SPERMATOGENESIS                        0.950303  0.232121
# HALLMARK_TGF_BETA_SIGNALING                     0.000000  0.246896
# HALLMARK_TNFA_SIGNALING_VIA_NFKB                0.000000  0.132126
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE              0.000000  0.002172
# HALLMARK_UV_RESPONSE_DN                         0.000000  0.002172
# HALLMARK_UV_RESPONSE_UP                         0.000000  1.000000
# HALLMARK_WNT_BETA_CATENIN_SIGNALING             0.990625  0.399600
# HALLMARK_XENOBIOTIC_METABOLISM                  0.950303  0.132126
